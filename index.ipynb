# %% [markdown]
# # Introduction to the Practice of Statistics
#
# This notebook is a way to quickly get started with statistical analysis.
#
# For examples of worked-through statistical analysis see the IPS9/ directory.
#
#
# # What's in this notebook
#
# ```
# IPS9/
# ├── data/           # Datasets for statistical examples
# ├── dotfiles/       # Installed by upstream image
# ├── IPS/            # Worked examples from the book
# ├── src/            # Core Common Lisp source code for the IPS examples
# ├── quicklisp/      # Quicklisp local projects and dependencies (if present)
# ├── work/           # Directory for your projects
# └── common-lisp-jupyter/ # CL kernel. If present do not delete
# ```
#
# # Your Analysis
# Your analysis begins below by loading the Lisp-Stat system

# %%
;;; Load Lisp-Stat
(ql:quickload :lisp-stat)
